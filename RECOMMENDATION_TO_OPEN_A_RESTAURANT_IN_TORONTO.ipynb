# %% [markdown]
# <a href="https://colab.research.google.com/github/minhnguyen10/The-Battle-of-Neighborhoods-/blob/master/RECOMMENDATION_TO_OPEN_A_RESTAURANT_IN_TORONTO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json # library to handle JSON files
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

from bs4 import BeautifulSoup
import lxml
import html5lib
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ### Part 1: Getting Canada Postal Code, Neighborhood, Borough

# %%
# url for CANADA Post Code from Wikipedia
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
res = requests.get(url)
soup = BeautifulSoup(res.content,"html.parser")

Canada_data = soup.find_all('table')[0] 
df = pd.read_html(str(Canada_data))[0]

# %%
df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
df.columns = ['PostalCode','Borough','Neighborhood']

# keep only columns that include an assigned borough, and ignor cells with a borough that is Not assigned
toronto_data = df[df['Borough']!= 'Not assigned']
toronto_data = toronto_data.reset_index(drop=True)
toronto_data.head()
# Out:
#   PostalCode           Borough                                 Neighborhood
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
toronto_data = toronto_data.groupby("PostalCode").agg(lambda x:','.join(set(x)))

# %%
na = toronto_data['Neighborhood'] == "Not assigned" #removed unassigned
toronto_data.loc[na, 'Neighborhood'] = toronto_data.loc[na, 'Borough']
toronto_data.reset_index(inplace=True)

# %%
#toronto_data
toronto_data.set_index(keys='PostalCode')
toronto_data.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Part 2: Import Latitude and Longitude of Postal Code

# %%
url = 'http://cocl.us/Geospatial_data'
df_gd = pd.read_csv(url)

# %%
df_gd.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#Merge with the Neighborhood df
df_gd.rename(columns={'Postal Code':'PostalCode'},inplace=True)
df_gd.set_index(keys='PostalCode')
toronto_gd = pd.merge(toronto_data, df_gd, on='PostalCode' )
toronto_gd.head()
# Out:
#   PostalCode      Borough  ...   Latitude  Longitude
# 0        M1B  Scarborough  ...  43.806686 -79.194353
# 1        M1C  Scarborough  ...  43.784535 -79.160497
# 2        M1E  Scarborough  ...  43.763573 -79.188711
# 3        M1G  Scarborough  ...  43.770992 -79.216917
# 4        M1H  Scarborough  ...  43.773136 -79.239476
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Part 3: Visualize Boroughs in Toronto on a map

# %%
toronto_boroughs= toronto_gd[toronto_gd['Borough'].str.contains('Toronto', na = False)].reset_index(drop=True)
toronto_boroughs.head()
# Out:
#   PostalCode          Borough  ...   Latitude  Longitude
# 0        M4E     East Toronto  ...  43.676357 -79.293031
# 1        M4K     East Toronto  ...  43.679557 -79.352188
# 2        M4L     East Toronto  ...  43.668999 -79.315572
# 3        M4M     East Toronto  ...  43.659526 -79.340923
# 4        M4N  Central Toronto  ...  43.728020 -79.388790
#
# [5 rows x 5 columns]

# %%
toronto_boroughs.shape
# Out:
# (39, 5)

# %%
address = 'Toronto, CAN'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6607002, -79.3850889.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(toronto_boroughs['Latitude'], toronto_boroughs['Longitude'], 
                           toronto_boroughs['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Part 4: Get and Explore Venues in Toronto using Foursquare API

# %%
CLIENT_ID = 'CAGK1X4MRSIPEPDKOPEOAPGVJ33N35RJ221UVWQXLN5N2O4R' # your Foursquare ID
CLIENT_SECRET = 'FH1CJV5PGB14RC5ES14L1QSE0RU4OBXQONO3LG3MTPYRRP41' # your Foursquare Secret
VERSION = '20201222' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: CAGK1X4MRSIPEPDKOPEOAPGVJ33N35RJ221UVWQXLN5N2O4R
# CLIENT_SECRET:FH1CJV5PGB14RC5ES14L1QSE0RU4OBXQONO3LG3MTPYRRP41

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)
toronto_venues = getNearbyVenues(names=toronto_boroughs['Neighborhood'],
                                   latitudes=toronto_boroughs['Latitude'],
                                   longitudes=toronto_boroughs['Longitude']
                                  )
# Out:
# The Beaches
# The Danforth West, Riverdale
# India Bazaar, The Beaches West
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West, Lawrence Park
# Davisville
# Moore Park, Summerhill East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Rosedale
# St. James Town, Cabbagetown
# Church and Wellesley
# Regent Park, Harbourfront
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# Roselawn
# Forest Hill North & West, Forest Hill Road Park
# The Annex, North Midtown, Yorkville
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Stn A PO Boxes
# First Canadian Place, Underground city
# Christie
# Dufferin, Dovercourt Village
# Little Portugal, Trinity
# Brockton, Parkdale Village, Exhibition Place
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Queen's Park, Ontario Provincial Government
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1599, 7)
#                    Neighborhood  ...     Venue Category
# 0                   The Beaches  ...              Trail
# 1                   The Beaches  ...  Health Food Store
# 2                   The Beaches  ...                Pub
# 3                   The Beaches  ...       Neighborhood
# 4  The Danforth West, Riverdale  ...   Greek Restaurant
#
# [5 rows x 7 columns]

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  ...  Venue Category
# Neighborhood                                                               ...
# Berczy Park                                                            57  ...              57
# Brockton, Parkdale Village, Exhibition Place                           23  ...              23
# Business reply mail Processing Centre, South Ce...                     16  ...              16
# CN Tower, King and Spadina, Railway Lands, Harb...                     16  ...              16
# Central Bay Street                                                     59  ...              59
# Christie                                                               16  ...              16
# Church and Wellesley                                                   78  ...              78
# Commerce Court, Victoria Hotel                                        100  ...             100
# Davisville                                                             35  ...              35
# Davisville North                                                        9  ...               9
# Dufferin, Dovercourt Village                                           14  ...              14
# First Canadian Place, Underground city                                100  ...             100
# Forest Hill North & West, Forest Hill Road Park                         5  ...               5
# Garden District, Ryerson                                              100  ...             100
# Harbourfront East, Union Station, Toronto Islands                     100  ...             100
# High Park, The Junction South                                          25  ...              25
# India Bazaar, The Beaches West                                         20  ...              20
# Kensington Market, Chinatown, Grange Park                              60  ...              60
# Lawrence Park                                                           4  ...               4
# Little Portugal, Trinity                                               43  ...              43
# Moore Park, Summerhill East                                             2  ...               2
# North Toronto West, Lawrence Park                                      18  ...              18
# Parkdale, Roncesvalles                                                 14  ...              14
# Queen's Park, Ontario Provincial Government                            30  ...              30
# Regent Park, Harbourfront                                              47  ...              47
# Richmond, Adelaide, King                                               96  ...              96
# Rosedale                                                                4  ...               4
# Roselawn                                                                3  ...               3
# Runnymede, Swansea                                                     33  ...              33
# St. James Town                                                         79  ...              79
# St. James Town, Cabbagetown                                            46  ...              46
# Stn A PO Boxes                                                         98  ...              98
# Studio District                                                        36  ...              36
# Summerhill West, Rathnelly, South Hill, Forest ...                     14  ...              14
# The Annex, North Midtown, Yorkville                                    19  ...              19
# The Beaches                                                             4  ...               4
# The Danforth West, Riverdale                                           43  ...              43
# Toronto Dominion Centre, Design Exchange                              100  ...             100
# University of Toronto, Harbord                                         33  ...              33
#
# [39 rows x 6 columns]

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 235 uniques categories.

# %%
Toronto_restaurants = toronto_venues[toronto_venues['Venue Category'].str.contains("Restaurant")]

# %%
print('There are {} unique cusines available in Toronto.'.format(len(Toronto_restaurants['Venue Category'].unique())))
# Out:
# There are 43 unique cusines available in Toronto.

# %% [markdown]
# ### Part 5: Cluster and Analyze neighborhoods

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(Toronto_restaurants[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = Toronto_restaurants['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()
# Out:
#                     Neighborhood  ...  Vietnamese Restaurant
# 4   The Danforth West, Riverdale  ...                      0
# 6   The Danforth West, Riverdale  ...                      0
# 10  The Danforth West, Riverdale  ...                      0
# 14  The Danforth West, Riverdale  ...                      0
# 15  The Danforth West, Riverdale  ...                      0
#
# [5 rows x 44 columns]

# %%
toronto_onehot.shape
# Out:
# (379, 44)

# %%
print('There are {} restaurants in Toronto with {} different style of cuisines.'.format(toronto_onehot.shape[0],(toronto_onehot.shape[1]-1)))
# Out:
# There are 379 restaurants in Toronto with 43 different style of cuisines.

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood  ...  Vietnamese Restaurant
# 0                                         Berczy Park  ...               0.000000
# 1        Brockton, Parkdale Village, Exhibition Place  ...               0.000000
# 2   Business reply mail Processing Centre, South C...  ...               0.000000
# 3                                  Central Bay Street  ...               0.000000
# 4                                            Christie  ...               0.000000
# 5                                Church and Wellesley  ...               0.000000
# 6                      Commerce Court, Victoria Hotel  ...               0.000000
# 7                                          Davisville  ...               0.000000
# 8                        Dufferin, Dovercourt Village  ...               0.000000
# 9              First Canadian Place, Underground city  ...               0.000000
# 10    Forest Hill North & West, Forest Hill Road Park  ...               0.000000
# 11                           Garden District, Ryerson  ...               0.050000
# 12  Harbourfront East, Union Station, Toronto Islands  ...               0.000000
# 13                      High Park, The Junction South  ...               0.000000
# 14                     India Bazaar, The Beaches West  ...               0.000000
# 15          Kensington Market, Chinatown, Grange Park  ...               0.166667
# 16                           Little Portugal, Trinity  ...               0.133333
# 17                  North Toronto West, Lawrence Park  ...               0.000000
# 18                             Parkdale, Roncesvalles  ...               0.000000
# 19        Queen's Park, Ontario Provincial Government  ...               0.000000
# 20                          Regent Park, Harbourfront  ...               0.000000
# 21                           Richmond, Adelaide, King  ...               0.000000
# 22                                 Runnymede, Swansea  ...               0.000000
# 23                                     St. James Town  ...               0.000000
# 24                        St. James Town, Cabbagetown  ...               0.000000
# 25                                     Stn A PO Boxes  ...               0.000000
# 26                                    Studio District  ...               0.000000
# 27  Summerhill West, Rathnelly, South Hill, Forest...  ...               0.250000
# 28                The Annex, North Midtown, Yorkville  ...               0.000000
# 29                       The Danforth West, Riverdale  ...               0.000000
# 30           Toronto Dominion Centre, Design Exchange  ...               0.000000
# 31                     University of Toronto, Harbord  ...               0.000000
#
# [32 rows x 44 columns]

# %%
toronto_grouped.shape
# Out:
# (32, 44)

# %% [markdown]
# Let's print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 3

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                            venue  freq
# 0             Seafood Restaurant  0.17
# 1                     Restaurant  0.17
# 2  Vegetarian / Vegan Restaurant  0.08
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#                    venue  freq
# 0     Italian Restaurant   0.5
# 1             Restaurant   0.5
# 2  Portuguese Restaurant   0.0
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                   venue  freq
# 0  Fast Food Restaurant   0.5
# 1            Restaurant   0.5
# 2   American Restaurant   0.0
#
#
# ----Central Bay Street----
#                    venue  freq
# 0     Italian Restaurant  0.19
# 1        Thai Restaurant  0.12
# 2  Portuguese Restaurant  0.06
#
#
# ----Christie----
#                    venue  freq
# 0     Italian Restaurant   0.5
# 1             Restaurant   0.5
# 2  Portuguese Restaurant   0.0
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0     Sushi Restaurant  0.19
# 1  Japanese Restaurant  0.19
# 2           Restaurant  0.11
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0           Restaurant  0.23
# 1   Italian Restaurant  0.13
# 2  Japanese Restaurant  0.10
#
#
# ----Davisville----
#                 venue  freq
# 0  Italian Restaurant   0.2
# 1    Sushi Restaurant   0.2
# 2   Indian Restaurant   0.1
#
#
# ----Dufferin, Dovercourt Village----
#                        venue  freq
# 0  Middle Eastern Restaurant   1.0
# 1        American Restaurant   0.0
# 2      Portuguese Restaurant   0.0
#
#
# ----First Canadian Place, Underground city----
#                  venue  freq
# 0           Restaurant  0.13
# 1  Japanese Restaurant  0.13
# 2  American Restaurant  0.10
#
#
# ----Forest Hill North & West, Forest Hill Road Park----
#                    venue  freq
# 0       Sushi Restaurant   1.0
# 1    American Restaurant   0.0
# 2  Portuguese Restaurant   0.0
#
#
# ----Garden District, Ryerson----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.15
# 1        Japanese Restaurant  0.15
# 2         Italian Restaurant  0.10
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                 venue  freq
# 0  Italian Restaurant  0.23
# 1          Restaurant  0.23
# 2    Sushi Restaurant  0.08
#
#
# ----High Park, The Junction South----
#                 venue  freq
# 0  Mexican Restaurant  0.29
# 1     Thai Restaurant  0.29
# 2  Italian Restaurant  0.14
#
#
# ----India Bazaar, The Beaches West----
#                   venue  freq
# 0  Fast Food Restaurant   0.4
# 1    Italian Restaurant   0.2
# 2      Sushi Restaurant   0.2
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                            venue  freq
# 0  Vegetarian / Vegan Restaurant  0.22
# 1          Vietnamese Restaurant  0.17
# 2             Mexican Restaurant  0.17
#
#
# ----Little Portugal, Trinity----
#                            venue  freq
# 0          Vietnamese Restaurant  0.13
# 1  Vegetarian / Vegan Restaurant  0.13
# 2                     Restaurant  0.13
#
#
# ----North Toronto West, Lawrence Park----
#                   venue  freq
# 0    Mexican Restaurant  0.25
# 1    Chinese Restaurant  0.25
# 2  Fast Food Restaurant  0.25
#
#
# ----Parkdale, Roncesvalles----
#                 venue  freq
# 0  Italian Restaurant  0.25
# 1    Cuban Restaurant  0.25
# 2          Restaurant  0.25
#
#
# ----Queen's Park, Ontario Provincial Government----
#                 venue  freq
# 0    Sushi Restaurant  0.33
# 1  Italian Restaurant  0.17
# 2  Mexican Restaurant  0.17
#
#
# ----Regent Park, Harbourfront----
#                 venue  freq
# 0  Mexican Restaurant  0.33
# 1   French Restaurant  0.33
# 2          Restaurant  0.33
#
#
# ----Richmond, Adelaide, King----
#                  venue  freq
# 0           Restaurant  0.17
# 1      Thai Restaurant  0.13
# 2  American Restaurant  0.09
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0  Italian Restaurant  0.22
# 1    Sushi Restaurant  0.22
# 2   French Restaurant  0.11
#
#
# ----St. James Town----
#                  venue  freq
# 0  American Restaurant  0.15
# 1           Restaurant  0.10
# 2  Moroccan Restaurant  0.10
#
#
# ----St. James Town, Cabbagetown----
#                  venue  freq
# 0   Italian Restaurant   0.2
# 1           Restaurant   0.2
# 2  Japanese Restaurant   0.1
#
#
# ----Stn A PO Boxes----
#                 venue  freq
# 0  Seafood Restaurant  0.18
# 1  Italian Restaurant  0.14
# 2          Restaurant  0.14
#
#
# ----Studio District----
#                      venue  freq
# 0      American Restaurant  0.25
# 1  Comfort Food Restaurant  0.12
# 2          Thai Restaurant  0.12
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                  venue  freq
# 0  American Restaurant  0.25
# 1           Restaurant  0.25
# 2     Sushi Restaurant  0.25
#
#
# ----The Annex, North Midtown, Yorkville----
#                        venue  freq
# 0          Indian Restaurant   0.5
# 1  Middle Eastern Restaurant   0.5
# 2        American Restaurant   0.0
#
#
# ----The Danforth West, Riverdale----
#                 venue  freq
# 0    Greek Restaurant  0.47
# 1  Italian Restaurant  0.18
# 2  Tibetan Restaurant  0.06
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                  venue  freq
# 0           Restaurant  0.15
# 1  American Restaurant  0.11
# 2  Japanese Restaurant  0.11
#
#
# ----University of Toronto, Harbord----
#                  venue  freq
# 0   Italian Restaurant  0.25
# 1  Japanese Restaurant  0.25
# 2     Sushi Restaurant  0.12

# %% [markdown]
# Let's put that into a pandas dataframe

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood  ...      10th Most Common Venue
# 0                                        Berczy Park  ...             Thai Restaurant
# 1       Brockton, Parkdale Village, Exhibition Place  ...        Ethiopian Restaurant
# 2  Business reply mail Processing Centre, South C...  ...        Ethiopian Restaurant
# 3                                 Central Bay Street  ...  Modern European Restaurant
# 4                                           Christie  ...        Ethiopian Restaurant
#
# [5 rows x 11 columns]

# %%
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 4, 0, 2, 4, 2, 2, 2, 1, 2], dtype=int32)

# %%
neighborhoods_venues_sorted = neighborhoods_venues_sorted.drop(['Cluster Labels'], axis=1, errors='ignore')
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = Toronto_restaurants

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
toronto_merged.fillna(0)
toronto_merged.head() # check the last columns!
# Out:
#                     Neighborhood  ...  10th Most Common Venue
# 4   The Danforth West, Riverdale  ...        Cuban Restaurant
# 6   The Danforth West, Riverdale  ...        Cuban Restaurant
# 10  The Danforth West, Riverdale  ...        Cuban Restaurant
# 14  The Danforth West, Riverdale  ...        Cuban Restaurant
# 15  The Danforth West, Riverdale  ...        Cuban Restaurant
#
# [5 rows x 18 columns]

# %%
toronto_merged['Cluster Labels'].value_counts()
# Out:
# 2    350
# 0     21
# 4      4
# 1      3
# 3      1
# Name: Cluster Labels, dtype: int64

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster, vc in zip(toronto_merged['Venue Latitude'], 
                                  toronto_merged['Venue Longitude'],
                                  toronto_merged['Venue'],
                                  toronto_merged['Cluster Labels'],
                                  toronto_merged['Venue Category'],):
    label = folium.Popup(str(poi) +' (' +str(vc) + ') ['+ str(cluster)+']', parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Examine Each cluster

# %%
c1 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[0] + list(range(8, toronto_merged.shape[1]))]]
c1.drop_duplicates()
# Out:
#                                            Neighborhood  ... 10th Most Common Venue
# 49                       India Bazaar, The Beaches West  ...   Ethiopian Restaurant
# 119                   North Toronto West, Lawrence Park  ...     Falafel Restaurant
# 317                           Regent Park, Harbourfront  ...   Ethiopian Restaurant
# 1483                      High Park, The Junction South  ...     Falafel Restaurant
# 1588  Business reply mail Processing Centre, South C...  ...   Ethiopian Restaurant
#
# [5 rows x 11 columns]

# %%
c2 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 1,toronto_merged.columns[[0] + list(range(8, toronto_merged.shape[1]))]]
c2.drop_duplicates()
# Out:
#                              Neighborhood  ... 10th Most Common Venue
# 1060  The Annex, North Midtown, Yorkville  ...   Ethiopian Restaurant
# 1402         Dufferin, Dovercourt Village  ...   Ethiopian Restaurant
#
# [2 rows x 11 columns]

# %%
c3 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 2,toronto_merged.columns[[0] + list(range(8, toronto_merged.shape[1]))]]
c3.drop_duplicates()
# Out:
#                                            Neighborhood  ...         10th Most Common Venue
# 4                          The Danforth West, Riverdale  ...               Cuban Restaurant
# 76                                      Studio District  ...           Fast Food Restaurant
# 136                                          Davisville  ...            Filipino Restaurant
# 173   Summerhill West, Rathnelly, South Hill, Forest...  ...             Falafel Restaurant
# 190                         St. James Town, Cabbagetown  ...              French Restaurant
# 235                                Church and Wellesley  ...              Indian Restaurant
# 365                            Garden District, Ryerson  ...          Vietnamese Restaurant
# 460                                      St. James Town  ...  Vegetarian / Vegan Restaurant
# 539                                         Berczy Park  ...                Thai Restaurant
# 598                                  Central Bay Street  ...     Modern European Restaurant
# 656                            Richmond, Adelaide, King  ...       Mediterranean Restaurant
# 767   Harbourfront East, Union Station, Toronto Islands  ...               Doner Restaurant
# 851            Toronto Dominion Centre, Design Exchange  ...           Fast Food Restaurant
# 951                      Commerce Court, Victoria Hotel  ...      Latin American Restaurant
# 1078                     University of Toronto, Harbord  ...               Asian Restaurant
# 1116          Kensington Market, Chinatown, Grange Park  ...           Colombian Restaurant
# 1188                                     Stn A PO Boxes  ...              Indian Restaurant
# 1285             First Canadian Place, Underground city  ...           Fast Food Restaurant
# 1418                           Little Portugal, Trinity  ...              Korean Restaurant
# 1509                             Parkdale, Roncesvalles  ...            Filipino Restaurant
# 1524                                 Runnymede, Swansea  ...           Fast Food Restaurant
# 1554        Queen's Park, Ontario Provincial Government  ...             Falafel Restaurant
#
# [22 rows x 11 columns]

# %%
c4 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 3,toronto_merged.columns[[0] + list(range(8, toronto_merged.shape[1]))]]
c4.drop_duplicates()
# Out:
#                                          Neighborhood  ... 10th Most Common Venue
# 1057  Forest Hill North & West, Forest Hill Road Park  ...   Ethiopian Restaurant
#
# [1 rows x 11 columns]

# %%
c5 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 4,toronto_merged.columns[[0] + list(range(8, toronto_merged.shape[1]))]]
c5.drop_duplicates()
# Out:
#                                       Neighborhood  ... 10th Most Common Venue
# 1388                                      Christie  ...   Ethiopian Restaurant
# 1461  Brockton, Parkdale Village, Exhibition Place  ...   Ethiopian Restaurant
#
# [2 rows x 11 columns]
